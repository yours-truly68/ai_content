# %% [markdown]
# ### Langchain Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent
from langchain.google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model_name = "google_genai:gemini-1.5-flash",
    google_api_key = os.getenv("GOOGLE_API_KEY"),
)

def get_weather(city:str) -> str:
    """Get the weather for a city"""
    return "The weather in {city} is sunny"
    

agent = create_agent(
    tools=[get_weather],
    model = llm,
    system_prompt = "You are a helpful assistant",
)
agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langchain.agents import create_agent
# ----> 2 from langchain.google_genai import ChatGoogleGenerativeAI
#       3
#       4 llm = ChatGoogleGenerativeAI(
#       5     model_name = "gemini-1.5-flash",
#
# ModuleNotFoundError: No module named 'langchain.google_genai'

# %%
agent.invoke({"messages": [{"role": "user", "content": "What is the weather like in Tokyo?"}]})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 agent.invoke({"messages": [{"role": "user", "content": "What is the weather like in Tokyo?"}]})
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py:3884, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3881             chunks.append(chunk)
#    3882 else:
#    3883     # v1: collect interrupts from updates stream
# -> 3884     for chunk in self.stream(
#    3885         input,
#    3886         config,
#    3887         context=context,
#    3888         stream_mode=(
#    3889             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3890         ),
#    3891         print_mode=print_mode,
#    3892         output_keys=output_keys,
#    3893         interrupt_before=interrupt_before,
#    3894         interrupt_after=interrupt_after,
#    3895         durability=durability,
#    3896         control=control,
#    3897         **kwargs,
#    3898     ):
#    3899         if stream_mode == "values":
#    3900             if len(chunk) == 2:
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py:2938, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2936 for task in loop.match_cached_writes():
#    2937     loop.output_writes(task.id, task.writes, cached=True)
# -> 2938 for _ in runner.tick(
#    2939     [t for t in loop.tasks.values() if not t.writes],
#    2940     timeout=self.step_timeout,
#    2941     get_waiter=get_waiter,
#    2942     schedule_task=loop.accept_push,
#    2943 ):
#    2944     # emit output
#    2945     yield from _output(
#    2946         stream_mode,
#    2947         print_mode,
#    (...)   2953         _state_mapper,
#    2954     )
#    2955 loop.after_tick()
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain/agents/factory.py:1335, in create_agent.<locals>.model_node(state, runtime)
#    1323 request = ModelRequest(
#    1324     model=model,
#    1325     tools=default_tools,
#    (...)   1331     runtime=runtime,
#    1332 )
#    1334 if wrap_model_call_handler is None:
# -> 1335     model_response = _execute_model_sync(request)
#    1336     return _build_commands(model_response)
#    1338 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain/agents/factory.py:1307, in create_agent.<locals>._execute_model_sync(request)
#    1304 if request.system_message:
#    1305     messages = [request.system_message, *messages]
# -> 1307 output = model_.invoke(messages)
#    1308 if name:
#    1309     output.name = name
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_core/runnables/base.py:5977, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5970 @override
#    5971 def invoke(
#    5972     self,
#    (...)   5975     **kwargs: Any | None,
#    5976 ) -> Output:
# -> 5977     return self.bound.invoke(
#    5978         input,
#    5979         self._merge_configs(config),
#    5980         **{**self.kwargs, **kwargs},
#    5981     )
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1668, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1666     _handle_openai_bad_request(e)
#    1667 except openai.APIError as e:
# -> 1668     _handle_openai_api_error(e)
#    1669 except Exception as e:
#    1670     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1663, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1656         return _construct_lc_result_from_responses_api(
#    1657             response,
#    1658             schema=original_schema_obj,
#    1659             metadata=generation_info,
#    1660             output_version=self.output_version,
#    1661         )
#    1662     else:
# -> 1663         raw_response = self.client.with_raw_response.create(**payload)
#    1664         response = raw_response.parse()
#    1665 except openai.BadRequestError as e:
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/openai/resources/chat/completions/completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# During task with name 'model' and id '37771bac-8b57-6c28-2d93-ef5b4c0cf15a'
