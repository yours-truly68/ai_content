# %% [markdown]
# ### Model Integration

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model#library used to initialise any kind of chat model

# model= init_chat_model("gpt-4.1")

model = init_chat_model(
    model = "groq:llama-3.3-70b-versatile", # best practice, you can also use init_chat_model(model = "llama-3.3-70b-versatile", model_provider = "groq")
)
model
# Out:
# ChatGroq(metadata={'versions': {'langchain-core': '1.4.6', 'langchain': '1.3.7'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x1133ee8b0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x1133ef230>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from langchain_groq import ChatGroq

#Initialising using ChatGroq

cloud_model = ChatGroq(
    model = "llama-3.3-70b-versatile",
)
cloud_model
# Out:
# ChatGroq(metadata={'versions': {'langchain-core': '1.4.6', 'langchain': '1.3.7'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x11397fac0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x113e18380>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %% [markdown]
# ### invoke the model

# %%
response = model.invoke("How many dollars were spent on for your pre-training on an estimate?")
response
# Out:
# AIMessage(content="Estimates of the cost of my pre-training vary, but it's reported that the development of my model and others like me required significant investments of computational resources and funding. \n\nMeta, the company that created me, has invested heavily in natural language processing research and development. The estimated cost of training a large language model like myself can range from $10 million to $30 million or more, depending on the specific requirements and the complexity of the model.\n\nHowever, it's essential to note that these estimates may not reflect the actual costs incurred by Meta, as the company hasn't publicly disclosed the exact figures. The costs also don't include the ongoing expenses associated with fine-tuning, updating, and maintaining the model over time.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 146, 'prompt_tokens': 49, 'total_tokens': 195, 'completion_time': 0.595228032, 'completion_tokens_details': None, 'prompt_time': 0.004191206, 'prompt_tokens_details': None, 'queue_time': 0.048227934, 'total_time': 0.599419238}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ebe85-deda-7470-9299-603c06afebe4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 146, 'total_tokens': 195})

# %%
response.content
# Out:
# "Estimates of the cost of my pre-training vary, but it's reported that the development of my model and others like me required significant investments of computational resources and funding. \n\nMeta, the company that created me, has invested heavily in natural language processing research and development. The estimated cost of training a large language model like myself can range from $10 million to $30 million or more, depending on the specific requirements and the complexity of the model.\n\nHowever, it's essential to note that these estimates may not reflect the actual costs incurred by Meta, as the company hasn't publicly disclosed the exact figures. The costs also don't include the ongoing expenses associated with fine-tuning, updating, and maintaining the model over time."

# %% [markdown]
# ### Streaming
# streaming is used to showcase the output in chunks instead of waiting for the entire response, making user experience progressively better

# %%
question = "Why is the sky blue? but not the sun even tho its the same source why isnt it blue like the rest of the sky?"

model.stream(question)

for chunk in model.stream(question):
    print(chunk.text, end = " ", flush=True)
# Out:
#  The  sky  appears  blue  because  of  a  phenomenon  called  Ray leigh  scattering ,  which  is  the  scattering  of  light  by  small  particles  or  molecules  in  the  atmosphere .  When  sunlight  enters  the  Earth 's  atmosphere ,  it  encounters  tiny  molecules  of  gases  such  as  nitrogen  ( N 2 )  and  oxygen  ( O 2 ).  These  molecules  scatter  the  light  in  all  directions ,  but  they  scatter  shorter  ( blue )  wavelengths  more  than  longer  ( red )  wavelengths .
#
#  This  is  because  the  smaller  molecules  are  more  effective  at  scattering  the  shorter  wavelengths ,  which  have  higher  frequencies  and  more  energy .  As  a  result ,  the  blue  light  is  distributed  throughout  the  atmosphere ,  giving  the  sky  its  blue  appearance .
#
#  Now ,  why  isn 't  the  sun  itself  blue ?  There  are  a  few  reasons  for  this :
#
#  1 .  ** Intensity **:  The  sun  is  an  incredibly  intense  source  of  light ,  and  its  brightness  overwhel ms  the  scattering  effect .  When  we  look  directly  at  the  sun ,  we 're  seeing  the  direct  light  from  the  sun ,  which  hasn 't  been  scattered  by  the  atmosphere .  This  direct  light  is  white ,  as  it  contains  all  the  wavelengths  of  visible  light .
#  2 .  ** W avelength  distribution **:  The  sun 's  light  is  made  up  of  all  the  wavelengths  of  visible  light ,  with  a  peak  intensity  in  the  yellow -green  part  of  the  spectrum  ( around   550  nan ometers ).  This  means  that  the  sun 's  light  is  not  predominantly  blue ,  but  rather  a  mix  of  all  colors .
#  3 .  ** Distance  and  atmosphere **:  When  we  look  at  the  sun ,  we 're  seeing  it  through  a  relatively  short  distance  of  atmosphere ,  which  doesn 't  have  a  significant  effect  on  the  color  of  the  light .  The  scattering  effect  that  makes  the  sky  appear  blue  is  more  pronounced  when  looking  at  the  atmosphere  from  a  distance ,  such  as  when  we  gaze  out  at  the  horizon .
#
#  In  contrast ,  when  we  look  at  the  sky ,  we 're  seeing  the  scattered  light  that  has  been  distributed  throughout  the  atmosphere .  This  scattered  light  is  predominantly  blue ,  which  is  why  the  sky  appears  blue .
#
#  So ,  to  summarize :  the  sky  appears  blue  because  of  Ray leigh  scattering ,  while  the  sun  itself  appears  white  or  yellow ish  due  to  its  intense  brightness ,  wavelength  distribution ,  and  the  relatively  short  distance  of  atmosphere  between  us  and  the  sun .

# %% [markdown]
# ### Batching
# Batching a collection of independent requests to the model, can significantly improve the performance and reduce costs, as the processing can be done in parallel.

# %%
responses = model.batch(
    [
        "The best dessert in the world?",
    "The best restaurant in the world?",
    "The best chef in the world?",
    "Which restaurant has the most michellin stars?",
    "Who is the best chef in the world?"
    
    ],
    config = {
        "max_concurrency" : 5 # maximum number of parallel processing or requests to handle at once
    }
)

for response in responses:
    print(response.content)
# Out:
# What a subjective and delicious question. The "best" dessert in the world is often a matter of personal taste, cultural background, and individual preferences. However, here are some of the most popular and iconic desserts from around the globe:
#
# 1. **Tiramisu** (Italy): A classic Italian dessert made with ladyfingers, mascarpone cheese, espresso, and cocoa powder.
# 2. **Crème Brûlée** (France): A rich custard base topped with a layer of caramelized sugar, typically served in small ramekins.
# 3. **Mochi** (Japan): A traditional Japanese dessert made from pounded glutinous rice, often filled with sweet fillings like red bean paste or ice cream.
# 4. **Cheesecake** (USA): A creamy and rich dessert made with a graham cracker crust, cream cheese, eggs, and sugar.
# 5. **Gulab Jamun** (India): A popular Indian dessert consisting of deep-fried dumplings soaked in a sweet and fragrant syrup made with rosewater and cardamom.
# 6. **Apple Strudel** (Austria): A classic pastry filled with apples, sugar, cinnamon, and sometimes raisins or nuts, topped with a crumbly streusel topping.
# 7. **Baklava** (Middle East): A sweet and nutty pastry made with layers of phyllo dough, honey, and chopped nuts like walnuts or pistachios.
# 8. **Panna Cotta** (Italy): An Italian dessert made with sweetened cream that's set with gelatin, flavored with vanilla, and topped with fruit sauce or caramel.
# 9. **Flan** (Mexico): A creamy and caramel-topped custard dessert that's a staple in Mexican cuisine.
# 10. **Black Forest Cake** (Germany): A chocolate cake made with whipped cream, cherries, and chocolate shavings, named after the Black Forest region in Germany.
#
# Of course, this is just a small sampling of the many amazing desserts from around the world. Ultimately, the "best" dessert is the one that makes your taste buds happy and leaves you wanting more.
#
# What's your favorite dessert?
# Determining the "best" restaurant in the world can be subjective, as opinions on food and dining experiences vary greatly from person to person. However, there are several restaurants that consistently receive high praise and accolades from critics, foodies, and travelers.
#
# Some of the top-ranked restaurants in the world, according to various sources such as Michelin guides, culinary awards, and reviews, include:
#
# 1. **Noma** (Copenhagen, Denmark): Known for its innovative and locally sourced Nordic cuisine, Noma has been named the Best Restaurant in the World four times.
# 2. **Mirazur** (Menton, France): This three-Michelin-starred restaurant offers breathtaking views of the Mediterranean and a menu that blends French and Italian flavors.
# 3. **Eleven Madison Park** (New York City, USA): A three-Michelin-starred restaurant located in the Flatiron District, Eleven Madison Park is known for its exquisite service, beautiful decor, and farm-to-table cuisine.
# 4. **Mugaritz** (Errenteria, Spain): This two-Michelin-starred restaurant in the Basque region of Spain is famous for its creative and avant-garde cuisine.
# 5. **Asador Etxebarri** (Axpe, Spain): This Michelin-starred restaurant in the Basque region is known for its traditional Spanish cuisine, with a focus on grilled meats and seafood.
# 6. **Gaggan** (Bangkok, Thailand): A two-Michelin-starred restaurant, Gaggan is known for its innovative and progressive Indian cuisine.
# 7. **Central** (Lima, Peru): This Michelin-starred restaurant is a pioneer of modern Peruvian cuisine, with a focus on local and sustainable ingredients.
# 8. **Maison Troisgros** (Roanne, France): A three-Michelin-starred restaurant, Maison Troisgros is known for its exquisite French cuisine and beautiful gardens.
# 9. **L'Atelier de Joël Robuchon** (Paris, France): A Michelin-starred restaurant, L'Atelier de Joël Robuchon is a unique dining experience, with a focus on counter seating and interactive cooking.
# 10. **Alinea** (Chicago, USA): A three-Michelin-starred restaurant, Alinea is known for its avant-garde and experimental cuisine, with a focus on molecular gastronomy.
#
# These are just a few examples of the many exceptional restaurants around the world. Ultimately, the "best" restaurant is a matter of personal taste and preference.
# What a question.  While opinions may vary, some of the most renowned and celebrated chefs in the world include:
#
# 1. **Joël Robuchon**: Late French chef, known for his Michelin-starred restaurants and innovative cuisine. He held the most Michelin stars of any chef in the world.
# 2. **Gordon Ramsay**: British chef, restaurateur, and TV personality, famous for his fiery personality and high culinary standards.
# 3. **Thomas Keller**: American chef, restaurateur, and owner of The French Laundry and Per Se, both three-Michelin-starred restaurants.
# 4. **René Redzepi**: Danish chef and owner of Noma, a two-Michelin-starred restaurant known for its innovative, foraging-based cuisine.
# 5. **Heston Blumenthal**: British chef and owner of The Fat Duck, a three-Michelin-starred restaurant famous for its experimental and scientific approach to cooking.
#
# However, if I had to pick one, I'd say **Joël Robuchon** is often considered the "best chef in the world" due to his:
#
# * Unprecedented 32 Michelin stars throughout his career
# * Innovative and influential cuisine
# * Mentorship of many famous chefs, including Gordon Ramsay
# * Legacy of Michelin-starred restaurants around the world
#
# Of course, this is subjective, and there are many other incredibly talented chefs who could be considered the "best" depending on personal taste and criteria.
# The restaurant with the most Michelin stars is the Mirazur, located in Menton, France, but as of the 2022 guide it now holds 3 stars. However, other restaurants have also achieved 3 stars.
#
# Historically though, the Japanese restaurant Kyoto's Gion Nanba, and the French restaurant Joël Robuchon, both held 3 stars in the Michelin guide, and were at the top of the list.
#
# However, since 2019, a new record has been set by the Alain Ducasse at The Dorchester, also a three-Michelin-starred restaurant, but also one with a total of 21 Michelin stars across all of its restaurants worldwide.
# What a subjective question. The "best" chef in the world is often a matter of personal opinion, as it depends on individual tastes, culinary styles, and criteria for evaluation. However, I can give you some insights based on various rankings, awards, and expert opinions.
#
# Some of the most renowned and celebrated chefs in the world include:
#
# 1. **Joël Robuchon** (late French chef): Often considered one of the greatest chefs of all time, Robuchon held 32 Michelin stars throughout his career.
# 2. **Thomas Keller** (American chef): Known for his exceptional culinary skills and attention to detail, Keller has earned three Michelin stars for his restaurants, The French Laundry and Per Se.
# 3. **Heston Blumenthal** (British chef): A pioneer of molecular gastronomy, Blumenthal has been awarded three Michelin stars for his restaurant, The Fat Duck.
# 4. **René Redzepi** (Danish chef): Founder of Noma, a two-Michelin-starred restaurant in Copenhagen, Redzepi is known for his innovative, farm-to-table approach to Nordic cuisine.
# 5. **Andoni Luis Aduriz** (Spanish chef): A two-Michelin-starred chef, Aduriz is recognized for his creative, avant-garde cuisine at his restaurant, Mugaritz.
#
# In recent years, some notable chefs have gained international recognition, such as:
#
# 1. **Gordon Ramsay** (British chef): A celebrity chef, restaurateur, and TV personality, Ramsay has earned 16 Michelin stars throughout his career.
# 2. **Massimo Bottura** (Italian chef): A three-Michelin-starred chef, Bottura is known for his innovative, artistic approach to Italian cuisine at his restaurant, Osteria Francescana.
# 3. **Alain Ducasse** (French chef): A legendary chef with 21 Michelin stars, Ducasse has been recognized for his exceptional culinary skills and dedication to promoting French cuisine.
#
# It's worth noting that there are many other talented chefs around the world who may not have received the same level of recognition or accolades, but are still highly respected within the culinary community.
#
# Ultimately, the "best" chef in the world is a matter of personal taste and opinion. Who is your favorite chef, or which culinary style do you enjoy the most?
