# %% [markdown]
# ### Model Integration

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model#library used to initialise any kind of chat model

model= init_chat_model("gpt-4.1")
model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 from langchain.chat_models import init_chat_model#library used to initialise any kind of chat model
#       2
#       3 model= init_chat_model("gpt-4.1")
# ----> 4 model_2 = init_chat_model("llama-3.3-70b-versatile")
#       5
#       6 model
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:494, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     486     warnings.warn(
#     487         f"{config_prefix=} has been set but no fields are configurable. Set "
#     488         f"`configurable_fields=(...)` to specify the model params that are "
#     489         f"configurable.",
#     490         stacklevel=2,
#     491     )
#     493 if not configurable_fields:
# --> 494     return _init_chat_model_helper(
#     495         cast("str", model),
#     496         model_provider=model_provider,
#     497         **kwargs,
#     498     )
#     499 if model:
#     500     kwargs["model"] = model
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:516, in _init_chat_model_helper(model, model_provider, **kwargs)
#     510 def _init_chat_model_helper(
#     511     model: str,
#     512     *,
#     513     model_provider: str | None = None,
#     514     **kwargs: Any,
#     515 ) -> BaseChatModel:
# --> 516     model, model_provider = _parse_model(model, model_provider)
#     517     creator_func = _get_chat_model_creator(model_provider)
#     518     return creator_func(model=model, **kwargs)
#
# File ~/Desktop/Coding/AI/LC_tutorial/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:621, in _parse_model(model, model_provider)
#     613     supported_list = ", ".join(sorted(_BUILTIN_PROVIDERS))
#     614     msg = (
#     615         f"Unable to infer model provider for {model=}. "
#     616         f"Please specify 'model_provider' directly.\n\n"
#    (...)    619         f"https://docs.langchain.com/oss/python/integrations/providers"
#     620     )
# --> 621     raise ValueError(msg)
#     623 # Normalize provider name
#     624 model_provider = model_provider.replace("-", "_").lower()
#
# ValueError: Unable to infer model provider for model='llama-3.3-70b-versatile'. Please specify 'model_provider' directly.
#
# Supported providers: anthropic, anthropic_bedrock, azure_ai, azure_openai, baseten, bedrock, bedrock_converse, cohere, deepseek, fireworks, google_anthropic_vertex, google_genai, google_vertexai, groq, huggingface, ibm, litellm, mistralai, nvidia, ollama, openai, openrouter, perplexity, together, upstage, xai
#
# For help with specific providers, see: https://docs.langchain.com/oss/python/integrations/providers
